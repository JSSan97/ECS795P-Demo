# %%
#@title Mount Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
#@title Clone Repo || Alternatively extract code contents (note the code is in my private github)
# %cd /content/drive/MyDrive/Github/
# !git clone https://<token>@github.com/JSSan97/ECS795P-Demo.git

# %%
#@title Pull Latest Changes, use only if cloned the repo
# %cd /content/drive/MyDrive/Github/ECS795P-Demo
# !git pull https://<token>@github.com/JSSan97/ECS795P-Demo.git

# %%
#@title Train
# %cd /content/drive/MyDrive/Github/ECS795P-Demo
# !python main.py --epochs=40 --model_name='ResNet101CBAM' --dataset='MNIST' --batch_size=64

# %%
#@title Test Images
# %cd /content/drive/MyDrive/Github/ECS795P-Demo
# %run experiment_images.py --dataset='MNISTFashion' --batch_size=8

# %%
#@title Test Plot
# %cd /content/drive/MyDrive/Github/ECS795P-Demo
# !python experiment_plotter.py --dataset='CIFAR10'
